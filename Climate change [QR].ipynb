# %% [markdown]
# <a href="https://colab.research.google.com/github/quynh-anh-bang/data/blob/main/Climate%20change%20%5BQR%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Climate change in Vietnam

# %% [markdown]
# ## Rising temperature

# %%
vn_01_21_url = "https://raw.githubusercontent.com/quynh-anh-bang/You-live-and-learn/main/observed-average-annual-mean-temperature-of-vietnam-for-1901-2021.csv"
vn_01_21 = pd.read_csv(vn_01_21_url)
vn_01_21
# Out:
#      Category  Annual Mean  5-yr smooth
# 0        1901        24.30        24.28
# 1        1902        24.37        24.30
# 2        1903        24.18        24.31
# 3        1904        24.11        24.32
# 4        1905        24.56        24.33
# ..        ...          ...          ...
# 116      2017        24.82        25.10
# 117      2018        24.80        25.12
# 118      2019        25.40        25.12
# 119      2020        25.22        25.12
# 120      2021        25.03        25.11
#
# [121 rows x 3 columns]

# %%
vn_01_21.describe()
# Out:
#           Category  Annual Mean  5-yr smooth
# count   121.000000   121.000000   121.000000
# mean   1961.000000    24.458678    24.459256
# std      35.073732     0.314799     0.241903
# min    1901.000000    23.750000    24.100000
# 25%    1931.000000    24.240000    24.260000
# 50%    1961.000000    24.400000    24.420000
# 75%    1991.000000    24.610000    24.600000
# max    2021.000000    25.420000    25.120000

# %%
plt.boxplot(vn_01_21["Annual Mean"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff0525cf190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff0525cf6d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff0525aeeb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff0525cfc10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff0525cfeb0>],
#  'means': []}

# %%
vn_01_21_clean = vn_01_21[(vn_01_21['Annual Mean']>=24.24)&(vn_01_21['Annual Mean']<=24.61)]

# %%
#selected in the video
vn_01_30 = vn_01_21[(vn_01_21["Category"]>= 1901)&(vn_01_21["Category"]<=1930)]

vn_01_30["Annual Mean"].plot(kind="density", label = "1901-1930")

vn_30_59 = vn_01_21[(vn_01_21["Category"]>= 1930)&(vn_01_21["Category"]<=1959)]
vn_30_59["Annual Mean"].plot(kind="density", label = "1930-1959")

vn_60_89 = vn_01_21[(vn_01_21["Category"]>= 1960)&(vn_01_21["Category"]<=1989)]
vn_60_89["Annual Mean"].plot(kind="density", label = "1960-1989")

vn_90_20 = vn_01_21[(vn_01_21["Category"]>= 1990)&(vn_01_21["Category"]<=2020)]
vn_90_20["Annual Mean"].plot(kind="density", label = "1990-2020")
plt.hist(vn_90_20["Annual Mean"], density = True)
plt.xlabel("Annual mean temperature")
plt.title("Distribution of annual mean temperature (1901 - 2020)")
plt.legend()
plt.show()

# %%
mean = vn_01_21['Annual Mean'].mean()
fig,axs = plt.subplots(1,2, figsize=(9,3))
axs[0].plot(vn_01_21['Annual Mean'])
axs[1].plot(vn_01_21['5-yr smooth'])
plt.title('Annual mean temperature in Vietnam (1901 - 2021)')
plt.xlabel('Number of years from 1901')
plt.ylabel('Annual mean temperature')
plt.axhline(y=mean,color ='r')

# %%
vn_90_19 = vn_01_21[(vn_01_21["Category"]>= 1990)&(vn_01_21["Category"]<=2019)]

# %%
vn_01_30["5-yr smooth"].plot(kind="density", label = "1901-1930")
vn_30_59["5-yr smooth"].plot(kind="density", label = "1930-1959")
vn_60_89["5-yr smooth"].plot(kind="density", label = "1960-1989")
vn_90_20["5-yr smooth"].plot(kind="density", label = "1990-2020")
plt.xlabel("5-year smooth temperature")
plt.title("Distribution of 5-year smooth temperature")
plt.legend()
plt.show()

# %% [markdown]
# ## Temperature and CO2 emission

# %%
vn_co2_url = "https://raw.githubusercontent.com/quynh-anh-bang/You-live-and-learn/main/API_EN.ATM.CO2E.KT_DS2_en_csv_v2_4898898.csv"
vn_co2 = pd.read_csv(vn_co2_url, skiprows=4)
vn_co2.head()
# Out:
#                   Country Name Country Code      Indicator Name  \
# 0                        Aruba          ABW  CO2 emissions (kt)
# 1  Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                  Afghanistan          AFG  CO2 emissions (kt)
# 3   Africa Western and Central          AFW  CO2 emissions (kt)
# 4                       Angola          AGO  CO2 emissions (kt)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...           2013  \
# 0  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...            NaN
# 1  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...  565430.012964
# 2  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...    5989.999771
# 3  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...  193299.997561
# 4  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...   26959.999084
#
#             2014           2015           2016           2017           2018  \
# ...

# %%
#vn: column AI(1990) to BL(2019)
vn_co2 = vn_co2[vn_co2["Country Name"]== "Vietnam"]
vn_co2_column = pd.concat([vn_co2["1990"],vn_co2["1991"],vn_co2["1992"],vn_co2["1993"],vn_co2["1994"],vn_co2["1995"],vn_co2["1996"],vn_co2["1997"],vn_co2["1998"],vn_co2["1999"],vn_co2["2000"],vn_co2["2001"],vn_co2["2002"],vn_co2["2003"],vn_co2["2004"],vn_co2["2005"],vn_co2["2006"],vn_co2["2007"],vn_co2["2008"],vn_co2["2009"],vn_co2["2010"],vn_co2["2011"],vn_co2["2012"],vn_co2["2013"],vn_co2["2014"],vn_co2["2015"],vn_co2["2016"],vn_co2["2017"],vn_co2["2018"],vn_co2["2019"]])
vn_co2_column
# Out:
# 257     19330.000000
# 257     19800.000000
# 257     20810.000000
# 257     24240.000000
# 257     26680.000000
# 257     31400.000000
# 257     35030.000000
# 257     40840.000000
# 257     45470.000000
# 257     46410.000000
# 257     51210.000000
# 257     56720.000000
# 257     66500.000000
# 257     70900.001526
# 257     85050.003052
# 257     92370.002747
# 257     94870.002747
# 257    105139.999390
# 257    117589.996338
# 257    132289.993286
# 257    151410.003662
# 257    155970.001221
# 257    155520.004272
# 257    164300.003052
# 257    180869.995117
# 257    220649.993896
# 257    223720.001221
# 257    230449.996948
# 257    285600.006104
# 257    336489.990234
# dtype: float64

# %%
xls = pd.ExcelFile('/content/statistic_id1288198_co2-emissions-asean-1960-2021-by-country.xlsx')
vn_co2_1=pd.read_excel(xls,'Data',skiprows=4)
vn_co2_1.head()
# Out:
#    Unnamed: 0 Unnamed: 1  Brunei  Cambodia  Indonesia  Laos  Malaysia  \
# 0         NaN       1960    0.33      0.23      21.39  0.08      4.20
# 1         NaN       1965    0.33      0.38      24.67  0.18      8.38
# 2         NaN       1970    8.20      1.15      35.79  0.57     14.59
# 3         NaN       1975    7.08      0.05      53.93  0.25     19.45
# 4         NaN       1980    6.88      0.29      94.87  0.19     28.03
#
#    Myanmar  Philippines  Singapore  Thailand  Vietnam
# 0     2.71         8.33       1.39      3.71     7.48
# 1     2.73        13.96       2.43      7.44    13.15
# 2     4.61        24.75      17.83     15.35    28.17
# 3     4.58        32.48      23.86     24.24    21.77
# 4     5.51        36.87      30.43     39.72    16.79

# %%
vn_01_21[vn_01_21['Category']==1960]
# Out:
#     Category  Annual Mean  5-yr smooth
# 59      1960        24.45        24.27

# %%
vn_temp_concat = pd.concat([vn_01_21['Annual Mean'][vn_01_21['Category']==1960],vn_01_21['Annual Mean'][vn_01_21['Category']==1965],vn_01_21['Annual Mean'][vn_01_21['Category']==1970],vn_01_21['Annual Mean'][vn_01_21['Category']==1975],vn_01_21['Annual Mean'][vn_01_21['Category']==1980],vn_01_21['Annual Mean'][vn_01_21['Category']==1985],vn_01_21['Annual Mean'][vn_01_21['Category']==1990],vn_01_21['Annual Mean'][vn_01_21['Category']==1995],vn_01_21['Annual Mean'][vn_01_21['Category']==2000],vn_01_21['Annual Mean'][vn_01_21['Category']==2005],vn_01_21['Annual Mean'][vn_01_21['Category']==2010],vn_01_21['Annual Mean'][vn_01_21['Category']==2015],vn_01_21['Annual Mean'][vn_01_21['Category']==2021]])
plt.scatter(vn_co2_1['Vietnam'],vn_temp_concat)
plt.xlabel("CO2 emission (in million metric tons of CO2)")
plt.ylabel("Annual mean temperature")

a,b = np.polyfit(vn_co2_1['Vietnam'],vn_temp_concat,1)
plt.plot(vn_co2_1['Vietnam'],a*vn_co2_1['Vietnam']+b, "r")
plt.title('Relationship between CO2 emission and annual mean temperature in Vietnam (1965-2021)')
plt.show()

# %%
np.corrcoef(vn_co2_1['Vietnam'],vn_temp_concat)
# Out:
# array([[1.        , 0.74108432],
#        [0.74108432, 1.        ]])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18,6))
fig.suptitle('Relationship between annual mean temperature and CO2 emission')

ax1.bar(vn_co2_1['Unnamed: 1'],vn_co2_1['Vietnam'])
ax1.set_ylabel('CO2 emission (in million metric tons of CO2)')
#ax1.title('CO2 emission in Vietnam (1960-2021)')

#ax2.plot(vn_01_21['5-yr smooth'])
ax2.plot(vn_temp_concat)
ax2.set_xlabel('Number of years from 1901')
ax2.set_ylabel('Annual mean temperature')

'''plt.show()
plt.bar(vn_co2_1['Unnamed: 1'],vn_co2_1['Vietnam'])
plt.ylabel('CO2 emission (in million metric tons of CO2)')
plt.xlabel('Year')
plt.title('CO2 emission in Vietnam (1960-2021)')'''
# Out:
# "plt.show()\nplt.bar(vn_co2_1['Unnamed: 1'],vn_co2_1['Vietnam'])\nplt.ylabel('CO2 emission (in million metric tons of CO2)')\nplt.xlabel('Year')\nplt.title('CO2 emission in Vietnam (1960-2021)')"

# %% [markdown]
# ## Descriptive statistics

# %%
vn_co2_column.describe()
# Out:
# count        30.000000
# mean     109587.666494
# std       85205.167378
# min       19330.000000
# 25%       41997.500000
# 50%       88710.002899
# 75%      155857.501984
# max      336489.990234
# dtype: float64

# %%
plt.boxplot(vn_co2_column,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff0456a0d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff0456b0280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff0456a0a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff0456b07c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff0456b0a60>],
#  'means': []}

# %% [markdown]
# # Climate change on a global scale

# %% [markdown]
# ## Rising temperature

# %%
global_80_22_url = "https://raw.githubusercontent.com/quynh-anh-bang/You-live-and-learn/main/GLB.Ts%2BdSST.csv"
global_80_22 = pd.read_csv(global_80_22_url, skiprows = 1, na_values = "***")
global_80_22.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.18 -0.24 -0.09 -0.16 -0.10 -0.21 -0.18 -0.10 -0.15 -0.23 -0.22
# 1  1881 -0.19 -0.14  0.03  0.05  0.06 -0.18  0.00 -0.03 -0.15 -0.22 -0.18
# 2  1882  0.16  0.14  0.04 -0.16 -0.14 -0.22 -0.17 -0.08 -0.15 -0.23 -0.17
# 3  1883 -0.29 -0.37 -0.12 -0.18 -0.18 -0.07 -0.07 -0.14 -0.22 -0.11 -0.24
# 4  1884 -0.13 -0.08 -0.36 -0.40 -0.34 -0.35 -0.30 -0.28 -0.27 -0.25 -0.33
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.17 -0.17   NaN   NaN -0.11 -0.16 -0.20
# 1 -0.07 -0.09 -0.09 -0.17  0.05 -0.07 -0.18
# 2 -0.36 -0.11 -0.09  0.08 -0.08 -0.16 -0.18
# 3 -0.11 -0.18 -0.20 -0.34 -0.16 -0.10 -0.19
# 4 -0.31 -0.28 -0.27 -0.11 -0.37 -0.31 -0.28

# %%
global_90_29 = global_80_22[(global_80_22["Year"]>=1890)&(global_80_22["Year"]<=1929)]
global_90_29["J-D"].plot(kind="density", label ="1890-1929")

global_30_69 = global_80_22[(global_80_22["Year"]>=1930)&(global_80_22["Year"]<=1969)]
global_30_69["J-D"].plot(kind="density", label ="1930-1969")

global_70_10 = global_80_22[(global_80_22["Year"]>=1970)&(global_80_22["Year"]<=2010)]
global_70_10["J-D"].plot(kind="density", label ="1970-2010")
plt.hist(global_70_10["J-D"], density = True)
plt.xlabel("Deviations from the 1951-1980 means")
plt.title('Distribution of variations in global temperature (1890 - 2010)')
plt.legend()

# %% [markdown]
# ## Descriptive statistics

# %%
global_80_22.describe()
# Out:
#               Year         Jan         Feb         Mar         Apr  \
# count   144.000000  144.000000  143.000000  143.000000  143.000000
# mean   1951.500000    0.064583    0.065524    0.081329    0.057063
# std      41.713307    0.421610    0.421128    0.423844    0.390281
# min    1880.000000   -0.810000   -0.630000   -0.630000   -0.590000
# 25%    1915.750000   -0.240000   -0.240000   -0.220000   -0.255000
# 50%    1951.500000   -0.015000   -0.040000    0.010000   -0.020000
# 75%    1987.250000    0.310000    0.375000    0.310000    0.280000
# max    2023.000000    1.170000    1.370000    1.360000    1.140000
#
#               May         Jun         Jul         Aug         Sep         Oct  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  143.000000
# mean     0.047832    0.033846    0.056993    0.055385    0.058601    0.085105
# std      0.371036    0.367101    0.346914    0.362126    0.359706    0.368032
# ...

# %%
plt.boxplot(global_90_29["J-D"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff0455de8b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff0455dedf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff0455de610>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff04556b370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff04556b610>],
#  'means': []}

# %% [markdown]
# ## Temperature and CO2 emission

# %%
#note: interpolated vs trend
co2data= pd.read_csv("https://raw.githubusercontent.com/quynh-anh-bang/You-live-and-learn/main/1_CO2-data.csv")
 #co2data["trend"] has the unit of month while global is in yr

# %%
co2data
# Out:
#      year  month  monthly_average  interpolated   trend
# 0    1958      3           315.71        315.71  314.62
# 1    1958      4           317.45        317.45  315.29
# 2    1958      5           317.50        317.50  314.71
# 3    1958      6           -99.99        317.10  314.85
# 4    1958      7           315.86        315.86  314.98
# ..    ...    ...              ...           ...     ...
# 708  2017      3           407.18        407.18  405.61
# 709  2017      4           409.00        409.00  406.12
# 710  2017      5           409.65        409.65  406.25
# 711  2017      6           408.84        408.84  406.53
# 712  2017      7           407.07        407.07  406.69
#
# [713 rows x 5 columns]

# %%
global_58_17 = global_80_22[(global_80_22["Year"]>=1958)&(global_80_22["Year"]<=2017)]
global_59_17 = global_80_22[(global_80_22["Year"]>=1959)&(global_80_22["Year"]<=2017)]
global_58_16 = global_80_22[(global_80_22["Year"]>=1958)&(global_80_22["Year"]<=2016)]
global_concat_1 = pd.concat([global_59_17["Jan"],global_59_17["Feb"],global_58_17["Mar"],global_58_17["Apr"],global_58_17["May"],global_58_17["Jun"],global_58_17["Jul"],global_58_16["Aug"],global_58_16["Sep"],global_58_16["Oct"],global_58_16["Nov"],global_58_16["Dec"]])

# %%
co2_1= co2data[co2data['month']==1]
co2_2= co2data[co2data['month']==2]
co2_3= co2data[co2data['month']==3]
co2_4= co2data[co2data['month']==4]
co2_5= co2data[co2data['month']==5]
co2_6= co2data[co2data['month']==6]
co2_7= co2data[co2data['month']==7]
co2_8= co2data[co2data['month']==8]
co2_9= co2data[co2data['month']==9]
co2_10= co2data[co2data['month']==10]
co2_11= co2data[co2data['month']==11]
co2_12= co2data[co2data['month']==12]
co2_concat = pd.concat([co2_1,co2_2,co2_3,co2_4,co2_5,co2_6,co2_7,co2_8,co2_9,co2_10,co2_11,co2_12])

# %%
plt.scatter(co2_concat['interpolated'],global_concat_1)
plt.xlabel("CO2 emission (kilotons)")
plt.ylabel("Global temperature anomalies")

a,b = np.polyfit(co2_concat['interpolated'],global_concat_1,1)
plt.plot(co2_concat['interpolated'],a*co2_concat['interpolated']+b, "r")
plt.title('Relationship between temperature anomalies and CO2 emission from 1958 to 2017')
plt.show()

# %%
np.corrcoef(co2_concat['interpolated'],global_concat_1)
# Out:
# array([[1.        , 0.89537504],
#        [0.89537504, 1.        ]])
